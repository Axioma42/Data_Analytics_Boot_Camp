# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# %%
# geocoordinates
target_coordinates = "19.403077832800,-99.154069716200"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "latlng":target_coordinates
}

# base url
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
base_url = "https://maps.googleapis.com/maps/api/geocode/json?key="+str(gkey)

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
#print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "plus_code": {
#         "compound_code": "CR3W+69 Mexico City, CDMX, Mexico",
#         "global_code": "76F2CR3W+69"
#     },
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "#462",
#                     "short_name": "#462",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Avenida Cuauht\u00e9moc",
#                     "short_name": "Av. Cuauht\u00e9moc",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Piedad Narvarte",
#                     "short_name": "Piedad Narvarte",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "Ciudad de M\u00e9xico",
#                     "short_name": "M\u00e9xico D.F.",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ciudad de M\u00e9xico",
#                     "short_name": "CDMX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "03000",
#                     "short_name": "03000",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Av. Cuauht\u00e9moc #462, Piedad Narvarte, 03000 Ciudad de M\u00e9xico, CDMX, Mexico",
#             "geometry": {
#                 "location": {
#                     "lat": 19.4030875,
#                     "lng": -99.1540907
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 19.4044364802915,
#                         "lng": -99.1527417197085
#                     },
#                     "southwest": {
#                         "lat": 19.4017385197085,
#                         "lng": -99.15543968029151
#                     }
#                 }
#             },
#             "place_id": "ChIJVVVVgBn_0YUROO2qLlpudQQ",
#             "plus_code": {
#                 "compound_code": "CR3W+69 Mexico City, Mexico",
#                 "global_code": "76F2CR3W+69"
#             },
#             "types": [
#                 "establishment",
#                 "food",
#                 "point_of_interest",
#                 "restaurant"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Piedad Narvarte",
#                     "short_name": "Piedad Narvarte",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "Ciudad de M\u00e9xico",
#                     "short_name": "M\u00e9xico D.F.",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ciudad de M\u00e9xico",
#                     "short_name": "CDMX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Piedad Narvarte, Ciudad de M\u00e9xico, CDMX, Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 19.4040632,
#                         "lng": -99.14973630000001
#                     },
#                     "southwest": {
#                         "lat": 19.4011862,
#                         "lng": -99.1622854
#                     }
#                 },
#                 "location": {
#                     "lat": 19.403193,
#                     "lng": -99.1556476
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 19.4040632,
#                         "lng": -99.14973630000001
#                     },
#                     "southwest": {
#                         "lat": 19.4011862,
#                         "lng": -99.1622854
#                     }
#                 }
#             },
#             "place_id": "ChIJ40LPyBv_0YURDB15til0TUU",
#             "types": [
#                 "political",
#                 "sublocality",
#                 "sublocality_level_1"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "03000",
#                     "short_name": "03000",
#                     "types": [
#                         "postal_code"
#                     ]
#                 },
#                 {
#                     "long_name": "Colonia del Valle Norte",
#                     "short_name": "Col del Valle Nte",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "Ciudad de M\u00e9xico",
#                     "short_name": "M\u00e9xico D.F.",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ciudad de M\u00e9xico",
#                     "short_name": "CDMX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Col del Valle Nte, 03000 Ciudad de M\u00e9xico, CDMX, Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 19.4037993,
#                         "lng": -99.1497601
#                     },
#                     "southwest": {
#                         "lat": 19.4009979,
#                         "lng": -99.16265510000001
#                     }
#                 },
#                 "location": {
#                     "lat": 19.403193,
#                     "lng": -99.1556476
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 19.4037993,
#                         "lng": -99.1497601
#                     },
#                     "southwest": {
#                         "lat": 19.4009979,
#                         "lng": -99.16265510000001
#                     }
#                 }
#             },
#             "place_id": "ChIJW3J6BBr_0YUR4iCBXCxeP3E",
#             "postcode_localities": [
#                 "Colonia del Valle Norte",
#                 "Piedad Narvarte"
#             ],
#             "types": [
#                 "postal_code"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Benito Juarez",
#                     "short_name": "Benito Juarez",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico City",
#                     "short_name": "M\u00e9xico D.F.",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico City",
#                     "short_name": "CDMX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Benito Juarez, Mexico City, CDMX, Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 19.4040632,
#                         "lng": -99.13094249999999
#                     },
#                     "southwest": {
#                         "lat": 19.3569176,
#                         "lng": -99.1921407
#                     }
#                 },
#                 "location": {
#                     "lat": 19.3794059,
#                     "lng": -99.15914459999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 19.4040632,
#                         "lng": -99.13094249999999
#                     },
#                     "southwest": {
#                         "lat": 19.3569176,
#                         "lng": -99.1921407
#                     }
#                 }
#             },
#             "place_id": "ChIJ21hOE6T_0YURCkUKiWXvHLM",
#             "types": [
#                 "administrative_area_level_3",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Mexico City",
#                     "short_name": "M\u00e9xico D.F.",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico City",
#                     "short_name": "CDMX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Mexico City, CDMX, Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 19.5927571,
#                         "lng": -98.9604482
#                     },
#                     "southwest": {
#                         "lat": 19.1887101,
#                         "lng": -99.3267771
#                     }
#                 },
#                 "location": {
#                     "lat": 19.4326077,
#                     "lng": -99.133208
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 19.5927571,
#                         "lng": -98.9604482
#                     },
#                     "southwest": {
#                         "lat": 19.1887101,
#                         "lng": -99.3267771
#                     }
#                 }
#             },
#             "place_id": "ChIJB3UJ2yYAzoURQeheJnYQBlQ",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Mexico City",
#                     "short_name": "CDMX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Mexico City, Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 19.5927571,
#                         "lng": -98.94030269999999
#                     },
#                     "southwest": {
#                         "lat": 19.0482366,
#                         "lng": -99.36492419999999
#                     }
#                 },
#                 "location": {
#                     "lat": 19.2464696,
#                     "lng": -99.1013498
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 19.5927571,
#                         "lng": -98.94030269999999
#                     },
#                     "southwest": {
#                         "lat": 19.0482366,
#                         "lng": -99.36492419999999
#                     }
#                 }
#             },
#             "place_id": "ChIJJyk1sTYAzoURW4rR6E6e_d4",
#             "types": [
#                 "administrative_area_level_1",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 32.7186534,
#                         "lng": -86.5887
#                     },
#                     "southwest": {
#                         "lat": 14.3895,
#                         "lng": -118.6523001
#                     }
#                 },
#                 "location": {
#                     "lat": 23.634501,
#                     "lng": -102.552784
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.7186534,
#                         "lng": -86.5887
#                     },
#                     "southwest": {
#                         "lat": 14.3895,
#                         "lng": -118.6523001
#                     }
#                 }
#             },
#             "place_id": "ChIJU1NoiDs6BIQREZgJa760ZO0",
#             "types": [
#                 "country",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
for result in places_data["results"]:
    print(result["name"])
    print(result["vicinity"])
# Out:
# Guang Zhou Restaurant
# 7609 W Overland Rd, Boise
# Guang Zhou Restaurant
# 7609 W Overland Rd, Boise
# China Grand Buffet
# 10498 W Fairview Ave, Boise
# Yen Ching Restaurant
# 305 N 9th St, Boise
# New Garden Chinese Restaurant
# 4624 W State St, Boise
# North End Chinese Restaurant
# 1806 W State St #3955, Boise
# P.F. Chang's
# 391 S 8th St, Boise
# Golden Star Restaurant
# 1142 N Orchard St, Boise
# Lucky Palace Chinese Restaurant
# 8630 W Overland Rd, Boise
# Great Wall Restaurant
# 10398 W Overland Rd, Boise
# Wok-Inn Noodle
# 4912 Emerald St, Boise
# Golden Wok
# 3948 W Chinden Blvd #6412, Boise
# Quik-Wok Restaurant
# 4858 W Overland Rd, Boise
# Season Wok
# 2775 Broadway Ave, Boise
# Mandarin Palace
# 5020 Franklin Rd, Boise
# Panda Express
# 7804 W Overland Rd, Boise
# Panda Express
# 1124 N Milwaukee St, Boise
# Panda Express
# 601 W Front St, Boise
# Panda Express
# 6675 N Glenwood St, Garden City
# Panda Express
# 1910 W University Dr, Boise
# Panda Express
# 350 N Milwaukee St, Boise
